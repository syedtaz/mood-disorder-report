# %% [markdown]
# ### Packages:
# - Car
# - Descr

# %%
setwd("/Users/tazmilur/Research/mood-disorder-prediction/analysis/MEQ5way/top/")
top_data <- read.csv('10feature_dataset.csv')

df <- data.frame(odds_ratio=numeric(), conf25=numeric(), conf75=numeric(), p_z=numeric(), name=character(), stringsAsFactors = FALSE)
for (i in 1:dim(top_data)[2]) {
  res = glm(MEQ ~ .,data=subset(top_data, select=c(i, ncol(top_data))),family=binomial())
  a <- c(exp(summary(res)$coef[2,][1]), confint(res)[2,], summary(res)$coef[2,][4], as.character(colnames(top_data)[i]))
  df[nrow(df) + 1,] = a
}
adjusted <- p.adjust(df[, c('p_z')], method="BH")
df$adjusted_p = adjusted

setwd("/Users/tazmilur/Research/mood-disorder-prediction/analysis/")
write.csv(df, 'top10MEQ_univariate.csv')
# Out:
# Waiting for profiling to be done...
# Waiting for profiling to be done...
# Waiting for profiling to be done...
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Waiting for profiling to be done...
# Waiting for profiling to be done...
# ...

# %%
setwd("/Users/tazmilur/Research/mood-disorder-prediction/analysis/STAI5way/top/")
top_data <- read.csv('10feature_dataset.csv')

multi = glm(STAI ~ ., data=top_data, family=binomial())
df = data.frame(odds_ratio=numeric(), multi_conf25=numeric(), multi_conf75=numeric(), multi_p_z=numeric(), name=character(), stringsAsFactors = FALSE)

for (i in seq(2, (length(summary(multi)$coef)/4), by=1)){
  trm <- attr(multi$terms, "term.labels")
  if (is.na(multi$coefficients[i])) {
    b <- c(NA, NA, NA, NA, trm[i-1])
    df[nrow(df) + 1,] = b
  } else {
    a <- tryCatch(confint(multi, trm[i-1]), error=function(e) c(NA,NA))
    b <- c(exp(summary(multi)$coef[i,][1]), a, summary(multi)$coef[i,][4], trm[i-1])
    df[nrow(df) + 1,] = b
    }
}

adjusted <- p.adjust(df[, c('multi_p_z')], method="BH")
df$multi_adjusted_p = adjusted

setwd("/Users/tazmilur/Research/mood-disorder-prediction/analysis/")
write.csv(df, 'top10STAI_multivariate.csv')
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Waiting for profiling to be done...
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”Warning message in regularize.values(x, y, ties, missing(ties)):
# ...

# %%
setwd("/Users/tazmilur/Research/mood-disorder-prediction/analysis/BDI5way/top/")
top_data <- read.csv('10feature_dataset.csv')
  
df = data.frame(fisher_p_z=numeric())

for (i in 1:(dim(top_data)[2]-1)){
  c <- descr::crosstab(top_data[,ncol(top_data)], top_data[,i], fisher=TRUE)
  df[nrow(df) + 1,] = c$fisher.ts$p.value
}

adjusted3 <- p.adjust(df[, c('fisher_p_z')], method="BH")
df$fisher_adjusted_p = adjusted3
df$names = colnames(top_data)[1:(dim(top_data)[2]-1)]

setwd("/Users/tazmilur/Research/mood-disorder-prediction/analysis/")
write.csv(df, 'top10BDI_fisher.csv')

# %%
df
